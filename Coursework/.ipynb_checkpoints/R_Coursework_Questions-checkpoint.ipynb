# %% [markdown]
# # R Coursework part 1

# %% [markdown]
# Answer all of the questions below in the cells provided.
#
# Make sure you:
#
# - comment your code
# - run your cells to check your answers
# - save your notebook with your answers before submitting it

# %% [markdown]
# ### Question 1

# %% [markdown]
# Create a data frame with 5 rows and 2 columns. The first column should be a vector of names of your choice, the second should be a series of numeric values.

# %%
# make two simple vectors
names_vec <- c("Amy", "Ali", "Tom", "Timmy", "Lily")
values_vec <- c(1, 2, 3, 4, 5)

# put them into a data frame
my_df <- data.frame(Name = names_vec, Value = values_vec)

my_df
# Out:
#   Name  Value
# 1 Amy   1
# 2 Ali   2
# 3 Tom   3
# 4 Timmy 4
# 5 Lily  5

# %% [markdown]
# ### Question 2

# %% [markdown]
# The code in the cell below provides examples of each of the main data structures in R. Run the code in the cell below.

# %%
my_vector <- seq(from = 1, to = 1000, by = 1)
my_matrix <- matrix(1:100, nrow = 10, ncol = 10)
my_dataframe <- data.frame(name = rep(c("a", "b"), each = 10), value = 21:40)
my_list <- list(my_vector, my_matrix, my_dataframe)

# %% [markdown]
# Show how to access:
#
# - The 4th value of the vector
# - Column 4 and row 7 of the matrix
# - The 10th value of name in the data.frame
# - The 5th element of the 1st element of the list

# %%
# 4th number in the vector
my_vector[4]

# row 7, col 4 in the matrix
my_matrix[7, 4]

# 10th item of the name column
my_dataframe$name[10]

# 5th item from the first part of the list
my_list[[1]][5]
# Out:
# [1] 4
# [1] 37
# [1] "a"
# [1] 5

# %% [markdown]
# ### Question 3

# %% [markdown]
# Show three different ways to print the numbers 200 to 300 in R. One should be a `for` loop, one should be an `sapply` function and the third can be a method of your choosing.

# %%
# for loop
for (i in 200:300) print(i)

# sapply
sapply(200:300, print)

# direct print
200:300
# Out:
# [1] 200
# [1] 201
# [1] 202
# [1] 203
# [1] 204
# [1] 205
# [1] 206
# [1] 207
# [1] 208
# [1] 209
# [1] 210
# [1] 211
# [1] 212
# [1] 213
# [1] 214
# [1] 215
# [1] 216
# [1] 217
# [1] 218
# [1] 219
# [1] 220
# [1] 221
# [1] 222
# [1] 223
# [1] 224
# [1] 225
# [1] 226
# [1] 227
# [1] 228
# [1] 229
# [1] 230
# [1] 231
# [1] 232
# [1] 233
# [1] 234
# [1] 235
# [1] 236
# [1] 237
# [1] 238
# [1] 239
# [1] 240
# [1] 241
# [1] 242
# [1] 243
# [1] 244
# [1] 245
# [1] 246
# [1] 247
# [1] 248
# [1] 249
# [1] 250
# [1] 251
# [1] 252
# [1] 253
# [1] 254
# [1] 255
# [1] 256
# [1] 257
# [1] 258
# [1] 259
# [1] 260
# [1] 261
# [1] 262
# [1] 263
# [1] 264
# [1] 265
# [1] 266
# [1] 267
# [1] 268
# [1] 269
# [1] 270
# [1] 271
# [1] 272
# [1] 273
# [1] 274
# [1] 275
# [1] 276
# [1] 277
# [1] 278
# [1] 279
     xlab = "Speed",
     ylab = "Distance",
     main = "Speed vs Distance")
# Out:
# Plot with title “Speed vs Distance”

# %% [markdown]
# ### Question 6

# %% [markdown]
# Using the `starwars` dataset, identify the individuals with:
#
# - the tallest height
# - the lowest mass
#
# HINT: the starwars dataset is part of the dplyr package

# %%
# load the dataset
library(dplyr)
data(starwars)

# tallest height
tallest <- starwars %>%  
  filter(height == max(height, na.rm = TRUE))

# lowest mass
lowest_mass <- starwars %>% 
  filter(mass == min(mass, na.rm = TRUE))

print(tallest)
print(lowest_mass)
# Out:
# # A tibble: 1 × 14
#   name      height  mass hair_color skin_color eye_color birth_year sex   gender
#   <chr>      <int> <dbl> <chr>      <chr>      <chr>          <dbl> <chr> <chr>
# 1 Yarael P…    264    NA none       white      yellow            NA male  mascu…
# # ℹ 5 more variables: homeworld <chr>, species <chr>, films <list>,
# #   vehicles <list>, starships <list>
# # A tibble: 1 × 14
#   name      height  mass hair_color skin_color eye_color birth_year sex   gender
#   <chr>      <int> <dbl> <chr>      <chr>      <chr>          <dbl> <chr> <chr>
# 1 Ratts Ty…     79    15 none       grey, blue unknown           NA male  mascu…
# # ℹ 5 more variables: homeworld <chr>, species <chr>, films <list>,
# #   vehicles <list>, starships <list>

# %% [markdown]
# ### Question 7

# %% [markdown]
# The `dplyr` dataset `storms` is part of the US National Oceanic and Atmospheric Administration database of Atlantic hurricanes. It contains multiple repeated measurements from hurricanes. For a given storm, there are measurements from every 6 hours across the life time of the storm.
#
# Use a tidyverse approach with `dplyr` to answer the following:
#
# - how many different storms are contained in the database?
# - which year had the most storms?
# - which storm, in which year had the highest pressure?
#
# HINT:
# unique() will help ensure you remove duplicated data from a vector e.g.
# x <- c(1, 1, 2, 2, 3, 3, 4, 4)
# unique(x)

# %%
# load the data
library(dplyr)
data(storms)

# how many different storms
n_distinct(storms$name)

# which year had the most storms
storms %>% 
  distinct(name, year) %>% 
  count(year) %>% 
  arrange(desc(n))

# which storm, in which year had the highest pressure
storms %>% 
  arrange(desc(pressure)) %>% 
  slice(1)
# Out:
# [1] 260
#    year n
# 1  2020 30
# 2  2005 29
# 3  1995 21
# 4  2003 21
# 5  2010 21
# 6  2011 20
# 7  2021 20
# 8  2012 19
# 9  2000 18
# 10 2017 18
# 11 2019 18
# 12 2001 17
# 13 2008 17
# 14 1999 16
# 15 2007 16
# 16 2016 16
# 17 2018 16
# 18 2022 16
# 19 2004 15
# 20 1990 14
# 21 1998 14
# 22 2002 14
# 23 2013 14
# 24 1996 13
# 25 1984 12
# 26 1988 12
# 27 1994 12
# 28 2015 12
# 29 1978 11
# 30 1980 11
# 31 1981 11
# 32 1985 11
# 33 1989 11
# 34 2006 11
# 35 2009 11
# 36 1991 10
# 37 1993 10
# 38 1992  9
# 39 2014  9
# 40 1975  8
# 41 1979  8
# 42 1997  8
# 43 1976  7
# 44 1987  7
# 45 1977  6
# 46 1986  6
# 47 1982  5
# 48 1983  4
#   name  year month day hour lat long status    category wind pressure
# 1 Danny 2003 7     27  0    31  -42  other low NA       20   1024
#   tropicalstorm_force_diameter hurricane_force_diameter
# 1 NA                           NA

# %% [markdown]
# ### Question 8

# %% [markdown]
# The `ggplot2` dataset `diamonds` contains the price and information from the sale of 54,000 different diamonds. You can use ?diamonds to find out more about the dataset if you want.
#
# Using `ggplot2`:
#
# - plot the relationship between the carat (i.e. the weight of the diamond) and the price.
# - plot a histogram of prices of all the diamonds
# - plot a boxplot of the difference in price between the different cuts

# %%
# load ggplot2
library(ggplot2)

# carat vs price
ggplot(diamonds, aes(x = carat, y = price)) +
  geom_point()

# a histogram of prices
ggplot(diamonds, aes(x = price)) +
  geom_histogram()

# a boxplot of the difference in price between the different cuts
ggplot(diamonds, aes(x = cut, y = price)) +
  geom_boxplot()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### Question 9

# %% [markdown]
# Identify the maximum and minimum price that the diamonds in the diamonds data set sold for. Add a new column to the diamonds data set that contains the string “Low price” if the value in the price column is less than 5000 dollars and “High price” if it is above 5000 dollars.

# %%
# find the max and min price
max_price <- max(diamonds$price)
min_price <- min(diamonds$price)

max_price
min_price

# new column: low or high price
for(i in 1:nrow(diamonds)) {
  if(diamonds$price[i] < 5000) {
    diamonds$price_group[i] <- "Low price"
  } else {
    diamonds$price_group[i] <- "High price"
  }
}

head(diamonds)
# Out:
# [1] 18823
# [1] 326
#   carat cut       color clarity depth table price x    y    z    price_group
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43 Low price
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31 Low price
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31 Low price
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63 Low price
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75 Low price
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48 Low price

# %% [markdown]
# ### Question 10

# %% [markdown]
# Sticking with the `diamonds` dataset for this question. A carat is a special unit of weight for gemstones where a single carat is 200 mg or 0.2 g. Write a function to convert the `diamonds$carat` vector into grams or milligrams. How heavy is the heaviest diamond?

# %%
# make a function to change carat into grams
# 1 carat = 0.2 g
carat_to_grams <- function(carat_value){
  grams <- carat_value * 0.2
  return(grams)
}

# use the function for the whole carat column
diamond_grams <- carat_to_grams(diamonds$carat)

# find the heaviest diamond in grams
heaviest_gram <- max(diamond_grams)

# also find in mg (just for comparison)
heaviest_mg <- heaviest_gram * 1000

heaviest_gram
heaviest_mg
# Out:
# [1] 1.002
# [1] 1002
