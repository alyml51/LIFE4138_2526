# %%
# load packages
library(dplyr)
library(readr)
library(ggplot2)

# read my own pumpkins file
pumpkins <- read_csv("../Pumpkins/pumpkins_datasets/pumpkins_15.csv")


# look at the data
head(pumpkins)
# Out:
# Rows: 15956 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (10): id, place, grower_name, city, state_prov, country, gpc_site, seed_...
# dbl  (5): weight_lbs, ott, est_weight, pct_chart, dataset_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   id     place weight_lbs grower_name      city        state_prov
# 1 2019-P 771    723.35133 Magarian, Marc   Midway      Utah
# 2 2016-P 1344   361.07132 Andres, Norbert  NA          Saxony
# 3 2020-P 96    1829.26272 Friesen, Dan     NA          Quebec
# 4 2019-P 1169   377.41027 Tittmann, Sven   Werder      Brandenburg
# 5 2015-P 849    751.38104 Pollock, Mark    Mill Creek  Nova Scotia
# 6 2020-P 1338    80.49146 Kuroda, Takahito Kuwana, Mie Other
#   country       gpc_site                                    seed_mother
# 1 United States Hee Haw Farms                               2077 Brandt
# 2 Germany       Saechsische Meisterschaft im Kurbiswiegen   NA
# 3 Canada        Port Elgin Pumpkinfest (Sunday)             2294 Noel
# 4 Germany       Wiegemeisterschaft Berlin/Brandenburg       NA
# 5 Canada        The Great Howard Dill Giant Pumpkin Classic 1253 Kline
# 6 Japan         Nippon Ichi Dodekabocha Taikai              NA
#   pollinator_father ott      est_weight pct_chart variety
# 1 Self              316.6190 749.2488   0.000000  Champion
# 2 NA                242.0854 322.0853   5.017957  Champion
# 3 SIB                 0.0000   0.0000   0.000000  Rouge Vif d’Etampes
# 4 NA                246.7432 426.6567   0.000000  Spirit
# 5 1389 Northrup       0.0000   0.0000   0.000000  Cinderella
# 6 NA                  0.0000   0.0000   0.000000  Big Moose
#   dataset_id
# 1 15
# 2 15
# 3 15
# 4 15
# 5 15
# 6 15

# %%
# make a year column from id (first 4 characters)
pumpkins$year <- substr(pumpkins$id, 1, 4)

# find the heaviest pumpkin 
heaviest <- pumpkins %>%
  filter(weight_lbs == max(weight_lbs, na.rm = TRUE))

heaviest
# Out:
#   id     place weight_lbs grower_name         city   state_prov    country
# 1 2016-P 1     2772.458   Vanden Bergh, Ronny Deurle East Flanders Belgium
#   gpc_site                            seed_mother   pollinator_father ott
# 1 Europameisterschaft im Kurbiswiegen 2145 McMullen 1872 Willemijns   542.3599
#   est_weight pct_chart variety        dataset_id year
# 1 2002.289   21.38719  Atlantic Giant 15         2016

# %%
library(dplyr)

# change lbs to kg
pumpkins <- pumpkins %>%
  mutate(weight_kg = weight_lbs * 0.453592)

head(pumpkins$weight_kg)
# Out:
# [1] 328.10638 163.77906 829.73894 171.19028 340.82043  36.51028

# %%
# make weight groups
pumpkins <- pumpkins %>%
  mutate(
    weight_class = ifelse(weight_kg < 200, "light",
                   ifelse(weight_kg < 500, "medium", "heavy"))
  )
# check it
table(pumpkins$weight_class)
# Out:
#  heavy  light medium
#   4039   4727   7190

# %%
library(ggplot2)

# plot: estimated vs actual weight
plot1 <- ggplot(pumpkins, aes(x = est_weight, y = weight_kg, color = weight_class)) +
  geom_point(alpha = 0.6) +
scale_color_manual(values = c("light" = "yellow", 
                                "medium" = "orange",
                                "heavy" = "red")) +
  labs(
    x = "Estimated weight (lbs)",
    y = "Actual weight (kg)",
    color = "Weight class",
    title = "Estimated vs actual pumpkin weight"
  ) +
  theme_minimal()

plot1

# save plot
ggsave("Pumpkins_R/plot_estimated_vs_actual.png", plot1)
# Out:
# Warning message:
# “Removed 401 rows containing missing values or values outside the scale range (`geom_point()`).”
# Saving 6.67 x 6.67 in image
# Warning message:
# “Removed 401 rows containing missing values or values outside the scale range (`geom_point()`).”
# plot without title

# %%
# check countries in the data
unique(pumpkins$country)

# keep three countries
pumpkins_three <- pumpkins %>%
  filter(country %in% c("Canada", "Japan", "Italy"))

# check it
table(pumpkins_three$country)

# save filtered data for the coursework
write_csv(pumpkins_three, "pumpkins_filtered.csv")
# Out:
#  [1] "United States"   "Germany"         "Canada"          "Japan"
#  [5] "United Kingdom"  "Austria"         "Italy"           "France"
#  [9] "Poland"          "Belgium"         "Slovenia"        "Switzerland"
# [13] "The Netherlands" "Finland"         "Spain"           "Portugal"
# [17] "New Zealand"     "Ireland"         "Luxembourg"      "Australia"
# [21] "Unknown country"
# Canada  Italy  Japan
#   2209    508    323

# %%
# mean weight by country 
mean_country <- pumpkins_three %>%
  group_by(country) %>%
  summarise(mean_weight = mean(weight_kg, na.rm = TRUE))

mean_country

# mean weight by country and variety
mean_variety <- pumpkins_three %>%
  group_by(country, variety) %>%
  summarise(mean_weight = mean(weight_kg, na.rm = TRUE)) %>%
  arrange(mean_weight)

mean_variety
# Out:
#   country mean_weight
# 1 Canada  350.8003
# 2 Italy   296.7949
# 3 Japan   138.9443
# `summarise()` has grouped output by 'country'. You can override using the `.groups` argument.
#    country variety             mean_weight
# 1  Japan   Wolf                101.7146
# 2  Japan   Atlantic Giant      106.0574
# 3  Japan   Dill's Atlantic     106.5600
# 4  Japan   Big Max             118.9892
# 5  Japan   Champion            122.9177
# 6  Japan   Cinderella          130.6058
# 7  Japan   Jack O'Lantern      131.7714
# 8  Japan   Prizewinner         137.0641
# 9  Japan   Howden              139.4031
# 10 Japan   Connecticut Field   145.3594
# 11 Japan   Early Giant         148.2585
# 12 Japan   Blue Hubbard        155.0897
# 13 Japan   Spirit              157.0834
# 14 Japan   Casper              157.5752
# 15 Japan   Rouge Vif d’Etampes 160.2964
# 16 Japan   Big Moose           160.6929
# 17 Japan   Autumn Gold         177.4395
# 18 Italy   Early Giant         222.9010
# 19 Italy   Howden              229.5532
# 20 Italy   Prizewinner         239.3429
# 21 Italy   Atlantic Giant      244.4968
# 22 Italy   Connecticut Field   263.3984
# 23 Italy   Jack O'Lantern      299.8555
# 24 Italy   Autumn Gold         300.9744
# 25 Italy   Rouge Vif d’Etampes 301.3961
# 26 Italy   Blue Hubbard        303.2897
# 27 Italy   Spirit              303.3980
# 28 Italy   Champion            312.2798
# 29 Italy   Wolf                314.8480
# 30 Italy   Cinderella          315.8678
# 31 Italy   Dill's Atlantic     319.4918
# 32 Canada  Wolf                325.3237
# 33 Italy   Big Moose           333.5959
# 34 Canada  Atlantic Giant      333.7644
# 35 Canada  Autumn Gold         333.8668
# 36 Canada  Connecticut Field   338.3186
# 37 Canada  Dill's Atlantic     338.9586
# 38 Canada  Cinderella          341.1430
# 39 Canada  Prizewinner         342.0093
# 40 Canada  Casper              342.8193
# 41 Canada  Big Max             349.9028
# 42 Canada  Jack O'Lantern      353.2294
# 43 Italy   Big Max             353.2448
# 44 Canada  Big Moose           354.6868
# 45 Canada  Howden              361.6772
# 46 Canada  Champion            363.8906
# 47 Canada  Rouge Vif d’Etampes 364.6011
# 48 Canada  Early Giant         364.8551
# 49 Italy   Casper              369.4345
# 50 Canada  Blue Hubbard        372.5774
# 51 Canada  Spirit              373.5968

# %%
library(ggplot2)

# boxplot for the three countries
box1 <- ggplot(pumpkins_three, aes(x = country, y = weight_kg)) +
  geom_boxplot(fill = "skyblue") +
  labs(
    x = "Country",
    y = "Pumpkin weight (kg)",
    title = "Weight distribution of pumpkins in three countries"
  ) +
  theme_minimal()

box1

# save boxplot
ggsave("Pumpkins_R/plot_boxplot_countries.png", box1,)
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
# facet plot by pumpkin variety
facet1 <- ggplot(pumpkins_three, aes(x = weight_kg)) +
  geom_histogram(binwidth = 100, fill = "skyblue") +
  facet_wrap(~ variety) +
  labs(
    x = "Pumpkin weight (kg)",
    y = "Count",
    title = "Pumpkin weight distribution by variety"
  ) +
  theme_minimal()

facet1

# save facet plot
ggsave("Pumpkins_R/plot_facet_variety.png", facet1,)
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
